# %%
# Import libraries
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from urllib.request import urlopen
from urllib.request import Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from config import my_tickers, my_headers

# %%
# 需要下載的新聞的數目 
news_number = 3 
tickers = my_tickers

# 新聞的URL
finviz_url = 'https://finviz.com/quote.ashx?t='
news_tables = {}

# %%
for ticker in tickers:
    url = finviz_url + ticker
    req = Request(url=url,headers=my_headers) 
    # 拿HTML
    resp = urlopen(req)
    # 解讀成為HTML碼 
    html = BeautifulSoup(resp, features="lxml")
    # 拿news-table內容
    news_table = html.find(id='news-table')
    # 每個ticker都有自己的新聞
    news_tables[ticker] = news_table

news_table
# Out:
# <table border="0" cellpadding="1" cellspacing="0" class="fullview-news-outer" id="news-table" width="100%">
# <tr><td align="right" style="white-space:nowrap" width="130">Jul-03-22 07:29PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.wsj.com/articles/bezos-criticizes-bidens-call-for-gas-stations-to-cut-prices-11656873702?siteid=yhoof2" target="_blank">Bezos Criticizes Bidens Call for Gas Stations to Cut Prices</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Wall Street Journal</span></div></div></td></tr>
# <tr><td align="right" width="130">07:03PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/oil-stabilizes-traders-weigh-recession-230348893.html" target="_blank">Oil Stabilizes as Traders Weigh Recession Concerns, Tight Supply</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">07:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/weshop-launches-first-community-owned-230100990.html" target="_blank">WeShop launches as first community-owned shopping platform with IPO in sight</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Independent</span></div></div></td></tr>
# <tr><td align="right" width="130">07:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-swap-vans-walking-cargo-230000228.html" target="_blank">Amazon to swap vans for walking and cargo bikes in Central London</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Independent</span></div></div></td></tr>
# <tr><td align="right" width="130">04:47PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.ft.com/cms/s/b7ac1a47-c42c-4eb1-90e6-f10b18693c72,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev" target="_blank">Jeff Bezos clashes with Biden administration again over inflation</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Financial Times</span></div></div></td></tr>
# <tr><td align="right" width="130">07:52AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/03/2-top-ai-stocks-for-a-bull-run/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Top AI Stocks Ready for a Bull Run</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" style="white-space:nowrap" width="130">Jul-02-22 12:42PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/amazon-champions-league-football-soccer-streaming-51656703902?siteid=yhoof2" target="_blank">Amazon Gets A Stronger Hold Of Sports Streaming, Wins Bid For Champions League Football</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">11:37AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/2-bargain-stocks-you-can-buy-today-and-hold-foreve/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Bargain Stocks You Can Buy Today and Hold Forever</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">10:35AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/you-wont-want-to-miss-this-dividend-stocks-bright/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">You Won't Want to Miss This Dividend Stock's Bright Future</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">08:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/will-this-spotify-acquisition-strengthen-ad-revenu/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Will This Spotify Acquisition Strengthen Ad Revenue?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:55AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/facebook-slams-brakes-on-hiring-sell-meta-stock/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Facebook Slams the Brakes on Hiring: Should You Sell Meta Stock?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:05AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/carvanas-stock-is-90-off-heres-why-its-a-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Carvana's Stock Is Down 90%. Here's Why It's a Buy</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:01AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/could-prologis-be-in-trouble/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Could Prologis Be in Trouble?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">06:53AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/02/stock-market-plunge-2-buffett-stocks-to-buy-now-an/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Stock Market Plunge: 2 Buffett Stocks to Buy Now and Hold Forever</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" style="white-space:nowrap" width="130">Jul-01-22 06:55PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/5-star-analyst-pounds-table-225507890.html" target="_blank">5-Star Analyst Pounds the Table on Amazon Stock</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TipRanks</span></div></div></td></tr>
# <tr><td align="right" width="130">04:44PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/fourth-july-deals-where-save-204401026.html" target="_blank">Fourth of July deals: Where to save on patio furniture, appliances, and mattresses</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">04:25PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.thestreet.com/personal-finance/espresso-machine-prime-day-sale?puc=yahoo&amp;cm_ven=YAHOO" target="_blank">Best-Selling Espresso Maker is Already 33% Off For Prime Day</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TheStreet.com</span></div></div></td></tr>
# <tr><td align="right" width="130">04:20PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/stocks-close-higher-10-treasury-202040607.html" target="_blank">Stocks close higher, 10-year Treasury yield drops, crude oil rises</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">01:28PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/why-amazon-mercadolibre-and-roku-stocks-moved-high/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Amazon, MercadoLibre, and Roku Stocks Moved Higher on Friday</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">12:51PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/meta-wants-to-be-more-ruthless-it-cant-fall-into-its-old-habits-165110289.html" target="_blank">Meta wants to be more ruthless. It can't fall into its old habits.</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">11:11AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/tesla-apple-microsoft-peloton-all-of-tech-companies-hitting-the-brakes-on-hiring-202428628.html" target="_blank">Meta, Coinbase, Tesla: All of the tech companies hitting the brakes on hiring</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">11:07AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/3-reasons-to-buy-amazon-stock-after-the-stock-spli/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Reasons to Buy Amazon Stock (After the Stock Split)</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">11:01AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/amazon-disney-t-donated-abortion-150142448.html" target="_blank">Amazon, Disney, AT&amp;T donated to abortion opponents, Tesla faces racial discrimination lawsuit</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">10:23AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/bond-markets-move-downside-mega-142337378.html" target="_blank">Bond markets move to the downside, mega cap tech stocks hold on to gains</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">10:11AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazons-amzn-mous-boost-expansion-141102805.html" target="_blank">Amazon's (AMZN) New MoUs Boost Expansion Strategy in India</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">09:57AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/gm-earnings-boy-cried-wolf-135718165.html" target="_blank">GM earnings: Its a boy that cried wolf, analyst says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">09:54AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/amazon-vs-microsoft-which-stock-is-the-better-buy/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Amazon vs. Microsoft Stock: Which is a Better Buy Right Now?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">09:35AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/why-albertsons-was-a-dog-of-a-stock-this-week/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Albertsons Was a Dog of a Stock This Week</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">08:52AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/michael-burry-latest-warning-bullwhip-125206248.html" target="_blank">Michael Burrys Latest Warning on Bullwhip Effect and 10 Retail Stocks to Watch</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
# <tr><td align="right" width="130">08:45AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/3-reasons-to-sell-a-stock-and-1-big-reason-not-to/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Reasons to Sell a Stock, and 1 Big Reason Not To</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">08:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/3-buffett-stocks-that-are-screaming-buys-right-now/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Buffett Stocks That Are Screaming Buys Right Now</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:52AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/beyond-stock-splits-3-top-growth-stocks-to-buy-now/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Beyond Stock Splits: 3 Top Growth Stocks to Buy Now</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:37AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/1-amazon-allow-prime-users-113757540.html" target="_blank">UPDATE 1-Amazon to allow Prime users to unsubscribe in two clicks after EU complaints</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">07:35AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/stock-market-dip-3-companies-buy-hold-long-term/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Stock Market Dip: 3 Companies to Buy and Hold for the Long Term</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:25AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/why-is-everyone-talking-about-bed-bath-beyond-stoc/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Is Everyone Talking About Bed Bath &amp; Beyond Stock?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:23AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.ft.com/cms/s/0de893be-ecdd-4430-9092-c873775716c2,s01=1.html?ftcamp=traffic/partner/feed_headline/us_yahoo/auddev" target="_blank">Amazon signs Champions League football streaming deal in UK</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Financial Times</span></div></div></td></tr>
# <tr><td align="right" width="130">07:11AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-allow-prime-users-unsubscribe-111139942.html" target="_blank">Amazon to allow Prime users to unsubscribe in two clicks after EU complaints</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">07:05AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-allow-prime-users-unsubscribe-110510599.html" target="_blank">Amazon to allow Prime users to unsubscribe in two clicks after EU complaints</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Reuters</span></div></div></td></tr>
# <tr><td align="right" width="130">07:01AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/salesforce-co-ceo-bret-taylor-110121885.html" target="_blank">Salesforce co-CEO Bret Taylor: Automation is crucial, even amid a slowing economy</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">07:01AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/2-reasons-to-buy-amazon-stock-now/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Reasons to Buy Amazon Stock Now</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">05:57AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/5-top-stocks-for-july/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">5 Top Stocks for July</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">05:21AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/07/01/better-stock-split-stock-to-buy-amazon-or-alphabet/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Better Stock-Split Stock to Buy Right Now: Amazon or Alphabet?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">12:39AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.bizjournals.com/seattle/news/2022/06/30/downtown-seattle-association-annual-meeting.html?utm_source=sy&amp;utm_medium=nsyp&amp;utm_campaign=yh" target="_blank">DSA says there's progress to report in effort to turn around downtown</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> American City Business Journals</span></div></div></td></tr>
# <tr><td align="right" style="white-space:nowrap" width="130">Jun-30-22 08:02PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/3-remarkable-growth-stocks-that-could-lead-the-mar/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Remarkable Growth Stocks That Could Lead the Market Recovery in the Second Half of 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:41PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/oracle-quietly-adds-abortion-travel-234134086.html" target="_blank">Oracle Quietly Adds Abortion Travel Reimbursement Benefits</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">06:27PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/the-ascent/personal-finance/articles/heres-how-to-get-60-in-free-money-for-amazon-prime-day-2022/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Here's How to Get $60 in Free Money for Amazon Prime Day 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">05:20PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/technology/amazon-stock-buy-now/?src=A00220" target="_blank">Is Amazon Stock A Buy Or Sell As Business Performance Hit By Big Events</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">05:06PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.bizjournals.com/seattle/news/2022/06/30/amazon-alicia-boler-davis-retail-pharmacy-startup.html?utm_source=sy&amp;utm_medium=nsyp&amp;utm_campaign=yh" target="_blank">Outgoing Amazon SVP tapped to lead Bay Area digital pharmacy startup</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> American City Business Journals</span></div></div></td></tr>
# <tr><td align="right" width="130">04:42PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/these-10-stocks-in-the-s-p-500-have-lost-4-1-trillion-of-investors-money-during-the-first-half-of-2022-11656599467?siteid=yhoof2" target="_blank">These 10 stocks in the S&amp;P 500 lost $4.2 trillion of investors money during the first half of 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">01:52PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/gabon-plans-world-biggest-ever-040000263.html" target="_blank">Worlds Biggest Ever Carbon Credits Issue Planned in Gabon</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">01:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/bed-bath-beyonds-liquidity-bofa-warns-174305790.html" target="_blank">Bed Bath &amp; Beyond's liquidity 'circles the drain,' BofA warns</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">01:01PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/despite-plenty-of-talk-many-u-s-companies-have-still-not-fully-exited-russia-moral-rating-agency-11656608500?siteid=yhoof2" target="_blank">Despite plenty of talk, many U.S. companies have still not fully exited Russia: Moral Rating Agency</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">01:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.thestreet.com/personal-finance/best-amazon-prime-day-deals?puc=yahoo&amp;cm_ven=YAHOO" target="_blank">The Best Early Amazon Prime Day Deals of 2022: Save on Tech, Home, and Fashion</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TheStreet.com</span></div></div></td></tr>
# <tr><td align="right" width="130">12:44PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazons-latest-move-reflects-appetite-164414709.html" target="_blank">Amazon's Latest Move Reflects Appetite For Expensive Sports Broadcast To Boost Prime Revenue</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Benzinga</span></div></div></td></tr>
# <tr><td align="right" width="130">12:26PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/top-research-reports-amazon-accenture-162604563.html" target="_blank">Top Research Reports for Amazon, Accenture &amp; Comcast</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">12:07PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/streaming-ads-waste-stranger-things-160755002.html" target="_blank">Some streaming ads go to waste, new 'Stranger Things' set to debut</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">12:00PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/lam-research-lrcx-proceeds-well-160004400.html" target="_blank">Lam Research (LRCX) Proceeds Well Toward Zero-Carbon Goals</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">11:44AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/why-amazon-apple-and-nvidia-are-falling-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Amazon, Apple, and Nvidia Are Falling Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">11:34AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/tech-stocks-nasdaq-having-worst-153444303.html" target="_blank">Tech stocks: Nasdaq having its worst year ever</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">11:20AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.investors.com/news/technology/amazon-prime-day-coming-with-another-in-fall/?src=A00220" target="_blank">Amazon Amps Up Its Prime Day And Plans Another During Fall</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Investor's Business Daily</span></div></div></td></tr>
# <tr><td align="right" width="130">10:50AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/10-small-cap-stocks-buy-145056317.html" target="_blank">10 Small-Cap Stocks to Buy According to Ken Fisher</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
# <tr><td align="right" width="130">10:43AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-blocks-lgbtq-searches-uae-144314404.html" target="_blank">Amazon blocks LGBTQ searches in UAE after political pressure</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Telegraph</span></div></div></td></tr>
# <tr><td align="right" width="130">10:18AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/market-check-stocks-sell-off-141855066.html" target="_blank">Market check: Stocks sell off, bitcoin dips below $19,000</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">09:57AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/5-high-conviction-stocks-to-buy-in-this-correction/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">5 High-Conviction Stocks to Buy in This Market Correction</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">09:41AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/walgreens-earnings-top-estimates-sales-134104068.html" target="_blank">Walgreens earnings top estimates, sales drop 4.2%</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">09:35AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/3-stocks-that-turned-1000-into-half-a-million-doll/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Stocks That Turned $1,000 Into Half a Million Dollars</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">09:02AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/cathie-wood-latest-thoughts-inflation-130248972.html" target="_blank">Cathie Woods Latest Thoughts on Inflation and Her 10 Worst-Performing Stock Picks</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Insider Monkey</span></div></div></td></tr>
# <tr><td align="right" width="130">08:20AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/2-reasons-to-buy-digitalocean-stock-and-1-reason-t/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Reasons to Buy DigitalOcean Stock, and 1 Reason to Sell</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">08:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/3-recent-stock-splits-that-are-begging-to-be-bough/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Recent Stock Splits That Are Begging to Be Bought</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">08:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/1-metric-all-investors-should-consider-before-buyi/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">1 Metric All Investors Should Consider Before Buying a New Stock</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">07:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.wsj.com/articles/finance-chiefs-weigh-costs-and-benefits-of-stock-splits-11656588600?siteid=yhoof2" target="_blank">Finance Chiefs Weigh Costs and Benefits of Stock Splits</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> The Wall Street Journal</span></div></div></td></tr>
# <tr><td align="right" width="130">06:37AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/amazon-vs-the-sp-500-which-is-the-better-first-inv/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Amazon vs. the S&amp;P 500: Which Is the Better First Investment?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">06:21AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/3-unstoppable-investments-everyone-needs-in-their/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">3 Unstoppable Investments Everyone Needs in Their Portfolios</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">06:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/influencers-andy-serwer-costis-maglaras-100000529.html" target="_blank">Influencers with Andy Serwer: Costis Maglaras</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">06:00AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/amazons-stock-split-impact-may-come-later/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Amazon's Stock Split Is Complete, but the Impact May Come Later</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">05:56AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/alphabet-tesla-investors-learn-amazon-stock-split/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">The Most Important Lesson Alphabet and Tesla Investors Can Learn From Amazon's Stock Split</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">05:30AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/30/do-stock-splits-mean-market-correction-imminent/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Do All These Stock Splits Mean a Market Correction Was Imminent?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">01:27AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/lenskart-buys-owndays-shares-bid-000000167.html" target="_blank">Lenskart in $400 Million Deal to Create Asian Eyewear Giant</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" style="white-space:nowrap" width="130">Jun-29-22 06:38PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/amazon-rite-aid-cap-purchase-of-plan-b-emergency-contraceptives-due-to-demand-01656542324?siteid=yhoof2" target="_blank">Amazon, Rite Aid cap purchase of Plan B emergency contraceptives due to demand</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">05:54PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/29/why-amazon-stock-rose-while-the-market-slept-today/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">Why Amazon Stock Rose While the Market Slept Today</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">05:52PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/plan-b-high-demand-roe-215239586.html" target="_blank">Plan B is in such high demand after Roe v. Wade was overturned that Amazon has limited purchases</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Fortune</span></div></div></td></tr>
# <tr><td align="right" width="130">05:45PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-amzn-gains-market-dips-214509186.html" target="_blank">Amazon (AMZN) Gains As Market Dips: What You Should Know</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">05:36PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.bizjournals.com/sanfrancisco/news/2022/06/29/veev-amazon-hayward-sublease-west-winton.html?utm_source=sy&amp;utm_medium=nsyp&amp;utm_campaign=yh" target="_blank">Veev takes more than 500,000 square feet in sublease from Amazon</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> American City Business Journals</span></div></div></td></tr>
# <tr><td align="right" width="130">05:03PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/roe-v-wade-companies-must-create-culture-of-psychological-safety-expert-says-210359675.html" target="_blank">Roe v. Wade: Companies must create culture of 'psychological safety,' expert says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">04:58PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/ceo-ousters-bed-bath-pinterest-stocks-51656524356?siteid=yhoof2" target="_blank">As Bed Bath and Pinterest Stocks Tumble, Their CEOs Are Collateral Damage</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">04:49PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/29/what-to-do-with-office-space-in-this-covid-world/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">What to Do With Office Space in This COVID World</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">04:11PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.barrons.com/articles/amazon-shares-could-triple-51656533499?siteid=yhoof2" target="_blank">Amazon Shares Could Nearly Triple From Here, One Analyst Says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Barrons.com</span></div></div></td></tr>
# <tr><td align="right" width="130">04:05PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-shares-worth-look-post-200508462.html" target="_blank">Are Amazon Shares Worth a Look Post-Split?</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Zacks</span></div></div></td></tr>
# <tr><td align="right" width="130">02:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.thestreet.com/technology/financier-chanos-sees-golden-opportunity-for-amazon-microsoft-google?puc=yahoo&amp;cm_ven=YAHOO" target="_blank">Financier Chanos Sees Golden Opportunity For Amazon, Microsoft, Google</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> TheStreet.com</span></div></div></td></tr>
# <tr><td align="right" width="130">02:43PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/challenges-facing-ousted-bed-bath-beyond-ceo-became-quickly-insurmountable-retail-expert-11656528191?siteid=yhoof2" target="_blank">Challenges facing ousted Bed Bath &amp; Beyond CEO became quickly insurmountable: retail expert</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">02:15PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/bed-bath-beyond-dumpster-fire-out-of-business-181505056.html" target="_blank">Bed Bath &amp; Beyond is 'in the end days' after 'dumpster fire' quarter, analyst says</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance</span></div></div></td></tr>
# <tr><td align="right" width="130">02:04PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/amazon-yelp-among-companies-that-will-cover-abortion-travel-costs-for-employees-11651611694?siteid=yhoof2" target="_blank">Companies covering abortion travel costs for employees now include Target, Yahoo and P&amp;G</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">01:50PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.marketwatch.com/story/stranger-things-and-beyond-heres-whats-worth-streaming-in-july-2022-11656525023?siteid=yhoof2" target="_blank">Stranger Things and beyond: Heres whats worth streaming in July 2022</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> MarketWatch</span></div></div></td></tr>
# <tr><td align="right" width="130">01:25PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/getting-mba-continues-incredibly-good-172506832.html" target="_blank">'Getting an MBA continues to be an incredibly good investment': Columbia Business School Dean</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">12:47PM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/amazon-plans-share-cashierless-store-164722837.html" target="_blank">Amazon Plans to Share Cashierless Store Data With Brands and Advertisers</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">11:26AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/ceo-resignations-668-executives-left-152649545.html" target="_blank">CEO resignations: 668 executives have left their posts since January</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">10:53AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://www.fool.com/investing/2022/06/29/2-reasons-why-mercadolibre-stock-can-bounce-back-b/?source=eptyholnk0000202&amp;utm_source=yahoo-host&amp;utm_medium=feed&amp;utm_campaign=article" target="_blank">2 Reasons MercadoLibre Can Bounce Back Big Time</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Motley Fool</span></div></div></td></tr>
# <tr><td align="right" width="130">10:29AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/video/mccormick-cuts-outlook-general-mills-142951521.html" target="_blank">McCormick cuts outlook, General Mills tops earnings estimates, Shopify stock split goes into effect</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Yahoo Finance Video</span></div></div></td></tr>
# <tr><td align="right" width="130">09:54AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/ecuador-president-lasso-survives-impeachment-043530914.html" target="_blank">Ecuador President Survives Impeachment Attempt Amid Unrest</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# <tr><td align="right" width="130">09:39AM  </td><td align="left"><div class="news-link-container"><div class="news-link-left"><a class="tab-link-news" href="https://finance.yahoo.com/news/jpmorgan-piles-estimate-cuts-earnings-133919606.html" target="_blank">JPMorgan Piles On With Estimate Cuts Before Earnings: Tech Watch</a></div><div class="news-link-right"><span style="color:#aa6dc0;font-size:9px"> Bloomberg</span></div></div></td></tr>
# </table>

# %%
# 使用 BeautifulSoup 和 requests 模塊從 FinViz 網站獲取新聞數據。
# 該代碼解析 HTML 新聞表的 URL，並遍歷代碼列表以收集每個代碼的最近標題。
# 對於每隻輸入的股票，都會打印出 n 個最近的標題，以便於查看數據。
try:
    for ticker in tickers:
        df = news_tables[ticker]
        df_tr = df.findAll('tr')
    
        print ('\n')
        print ('Recent News Headlines for {}: '.format(ticker))
        
        for i, table_row in enumerate(df_tr):
            a_text = table_row.a.text
            td_text = table_row.td.text
            td_text = td_text.strip()
            print(a_text,'(',td_text,')')
            if i == news_number-1:
                break
except KeyError:
    pass
# Out:
# Recent News Headlines for AAPL:
# Theyll chicken out: Fund legend Rick Rule says the Fed wont keep hiking rates aggressively, even to prevent amazing damage. Here are 3 spots he likes for your money ( Jul-03-22 04:35PM )
# Worried About Personal Data Leaks? Heres How to Lock Down Your Phone ( 10:00AM )
# Learn This Investing Lesson, And You'll Have the Key to Success ( 05:45AM )
#
#
# Recent News Headlines for TSLA:
# Dow Jones Futures Fall: Don't Feed The Bear; BYD Leaves Tesla In The Dust ( Jul-03-22 07:49PM )
# California Governor Newsom Runs Ads in Florida Attacking GOP ( 12:23PM )
# Teslas second-quarter sales drop amid supply-chain and other pandemic-linked problems ( 11:40AM )
#
#
# Recent News Headlines for AMZN:
# Bezos Criticizes Bidens Call for Gas Stations to Cut Prices ( Jul-03-22 07:29PM )
# Oil Stabilizes as Traders Weigh Recession Concerns, Tight Supply ( 07:03PM )
# WeShop launches as first community-owned shopping platform with IPO in sight ( 07:01PM )

# %%
# 為了執行情緒分析，數據必須採用正確的格式，因此這段代碼會遍歷收集到的新聞，
# 並將其分類為包含代碼、日期、時間和實際標題的列表。
parsed_news = []
for file_name, news_table in news_tables.items():
    for x in news_table.findAll('tr'):
        text = x.a.get_text() 
        date_scrape = x.td.text.split()

        if len(date_scrape) == 1:
            time = date_scrape[0]
            
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        ticker = file_name.split('_')[0]
        
        parsed_news.append([ticker, date, time, text])

parsed_news
# Out:
# [['AAPL',
#   'Jul-03-22',
#   '04:35PM',
#   'Theyll chicken out: Fund legend Rick Rule says the Fed wont keep hiking rates aggressively, even to prevent amazing damage. Here are 3 spots he likes for your money'],
#  ['AAPL',
#   'Jul-03-22',
#   '10:00AM',
#   'Worried About Personal Data Leaks? Heres How to Lock Down Your Phone'],
#  ['AAPL',
#   'Jul-03-22',
#   '05:45AM',
#   "Learn This Investing Lesson, And You'll Have the Key to Success"],
#  ['AAPL',
#   'Jul-02-22',
#   '02:00PM',
#   'Here Are 2 of the Best Stocks to Buy if the U.S. Avoids a Recession'],
#  ['AAPL',
#   'Jul-02-22',
#   '09:00AM',
#   'Will the Apple and MLS Deal Attract a New Generation?'],
#  ['AAPL',
#   'Jul-02-22',
#   '07:00AM',
#   'Its so horrible that I want to buy it  Jim Cramer likes these 2 crushed tech stocks that are still posting white-hot revenue growth'],
#  ['AAPL',
#   'Jul-02-22',
#   '07:00AM',
#   'Is Apple Dictating the Future of Sports Streaming?'],
#  ['AAPL',
#   'Jul-02-22',
#   '06:32AM',
#   'More Americans Are Using Digital Wallets Than Ever. Which One Should You Choose Right Now?'],
#  ['AAPL',
#   'Jul-02-22',
#   '06:30AM',
#   'How Many of Your Stocks Are Based in California? (And Is That a Bad Thing?)'],
#  ['AAPL',
#   'Jul-01-22',
#   '06:45PM',
#   'Texas Instruments Stock Is Trading at a Discount'],
#  ['AAPL',
#   'Jul-01-22',
#   '05:37PM',
#   'President Biden will posthumously award Steve Jobs the Presidential Medal of Freedom'],
#  ['AAPL',
#   'Jul-01-22',
#   '04:55PM',
#   "Alphabet's (GOOGL) Google Docs to Bring eSignature Feature"],
#  ['AAPL',
#   'Jul-01-22',
#   '04:53PM',
#   'Big-name investors are back putting more junk in their funds, despite the carnage in bonds'],
#  ['AAPL',
#   'Jul-01-22',
#   '04:50PM',
#   'What the Grateful Dead and the stock market have in common'],
#  ['AAPL',
#   'Jul-01-22',
#   '04:04PM',
#   "Stock market news lives updates: Stocks kicks of July with gains after the S&P 500's worst first half since 1970"],
#  ['AAPL',
#   'Jul-01-22',
#   '03:33PM',
#   'Apple: The iPhone Upgrade Cycle Is Underappreciated, Says 5-Star Analyst'],
#  ['AAPL',
#   'Jul-01-22',
#   '01:13PM',
#   'Apple facing full trial over anti-competitive App Store practices claim'],
#  ['AAPL',
#   'Jul-01-22',
#   '01:10PM',
#   "Meta could be 'bracing for a tornado-like quarter': Wedbush's Dan Ives"],
#  ['AAPL',
#   'Jul-01-22',
#   '11:54AM',
#   'Apple Stock Is Under Pressure. Why Its Earnings Could Trigger a Rebound.'],
#  ['AAPL',
#   'Jul-01-22',
#   '11:45AM',
#   "This Famous 'Big Short' Investor Is Betting Big Against Apple, but Buying This Stock"],
#  ['AAPL',
#   'Jul-01-22',
#   '11:30AM',
#   'Are Netflix and Roku a Match Made in Heaven?'],
#  ['AAPL',
#   'Jul-01-22',
#   '11:20AM',
#   "[video]AAP Daily Rundown: Friday's Market, Semiconductors, Charts"],
#  ['AAPL',
#   'Jul-01-22',
#   '11:11AM',
#   'Meta, Coinbase, Tesla: All of the tech companies hitting the brakes on hiring'],
#  ['AAPL',
#   'Jul-01-22',
#   '10:23AM',
#   'Bond markets move to the downside, mega cap tech stocks hold on to gains'],
#  ['AAPL',
#   'Jul-01-22',
#   '10:03AM',
#   '3 Dividend-Paying Tech Stocks to Buy in July'],
#  ['AAPL', 'Jul-01-22', '10:00AM', "3 Green Flags for Snap's Future"],
#  ['AAPL',
#   'Jul-01-22',
#   '09:57AM',
#   'GM earnings: Its a boy that cried wolf, analyst says'],
#  ['AAPL',
#   'Jul-01-22',
#   '09:44AM',
#   'Trimming and Downgrading One Stock, While Downgrading Another'],
#  ['AAPL',
#   'Jul-01-22',
#   '09:38AM',
#   'China Tech Rally Sends Insiders Rushing for Exits: Tech Watch'],
#  ['AAPL',
#   'Jul-01-22',
#   '08:31AM',
#   'Better Augmented Reality Stock: Apple vs. Nvidia'],
#  ['AAPL',
#   'Jul-01-22',
#   '08:00AM',
#   "Warren Buffett says these are the best stocks to own when inflation spikes  with consumer prices still raging, it's time to follow his lead"],
#  ['AAPL',
#   'Jul-01-22',
#   '06:28AM',
#   'Why Goldman is still very cautious on the stock market'],
#  ['AAPL', 'Jul-01-22', '06:15AM', 'This News Is a Game Changer for Solana'],
#  ['AAPL',
#   'Jul-01-22',
#   '05:30AM',
#   'The iPhones Creators Reveal the Consequences They Never Expected'],
#  ['AAPL',
#   'Jul-01-22',
#   '12:26AM',
#   'Apple hikes Japan price of iPhone by nearly a fifth'],
#  ['AAPL',
#   'Jun-30-22',
#   '10:20PM',
#   'Google Makes Deal With Developers in Latest App Store Shift'],
#  ['AAPL',
#   'Jun-30-22',
#   '09:03PM',
#   'UPDATE 1-Google to pay $90 mln to settle legal fight with app developers'],
#  ['AAPL',
#   'Jun-30-22',
#   '08:33PM',
#   'Apple Hikes iPhone and\xa0iPad Prices in Japan After Yen Tanks'],
#  ['AAPL',
#   'Jun-30-22',
#   '08:21PM',
#   'Google to pay $90 million to settle legal fight with app developers'],
#  ['AAPL',
#   'Jun-30-22',
#   '08:17PM',
#   'Google to pay $90 million to settle legal fight with app developers'],
#  ['AAPL',
#   'Jun-30-22',
#   '07:50PM',
#   'Former Apple lawyer pleads guilty over insider trading scheme'],
#  ['AAPL',
#   'Jun-30-22',
#   '07:41PM',
#   'Oracle Quietly Adds Abortion Travel Reimbursement Benefits'],
#  ['AAPL',
#   'Jun-30-22',
#   '06:20PM',
#   'When in Doubt, Zoom Out; Bear Markets Are a Goldmine'],
#  ['AAPL',
#   'Jun-30-22',
#   '06:06PM',
#   'Former Apple Lawyer Pleads Guilty to Insider Trading'],
#  ['AAPL',
#   'Jun-30-22',
#   '04:42PM',
#   'These 10 stocks in the S&P 500 lost $4.2 trillion of investors money during the first half of 2022'],
#  ['AAPL',
#   'Jun-30-22',
#   '04:29PM',
#   'Stocks Close Lower; Nasdaq Posts Record-Setting Loss In First Half'],
#  ['AAPL',
#   'Jun-30-22',
#   '04:20PM',
#   'Apples former corporate law director pleads guilty to insider trading'],
#  ['AAPL',
#   'Jun-30-22',
#   '04:14PM',
#   'Former top Apple lawyer pleads guilty to insider trading'],
#  ['AAPL',
#   'Jun-30-22',
#   '04:10PM',
#   'Stocks slide to close worst first half in 52 years: S&P 500 plunges 20.6% YTD, 8.4% in June'],
#  ['AAPL',
#   'Jun-30-22',
#   '04:03PM',
#   'Android Smartphone Makers Cutting Orders, But Apple Holds Firm'],
#  ['AAPL',
#   'Jun-30-22',
#   '02:56PM',
#   'How to protect your data in a post Roe v Wade world'],
#  ['AAPL',
#   'Jun-30-22',
#   '02:39PM',
#   'Comcasts Xfinity TV Streaming App Now Available on Apple TV Devices'],
#  ['AAPL',
#   'Jun-30-22',
#   '02:32PM',
#   'Apple has ended imports of gold and tungsten from Russia'],
#  ['AAPL',
#   'Jun-30-22',
#   '02:30PM',
#   "Is Pinterest's CEO Change Good News? It Depends on How You Look at It"],
#  ['AAPL',
#   'Jun-30-22',
#   '02:27PM',
#   'Enjoy Technology, Led by Ex-Apple Executive Ron Johnson, Files for Chapter 11 to Sell Itself'],
#  ['AAPL',
#   'Jun-30-22',
#   '01:32PM',
#   'The Apple Watch Series 7 is Just $312 on Amazon'],
#  ['AAPL',
#   'Jun-30-22',
#   '12:07PM',
#   "Some streaming ads go to waste, new 'Stranger Things' set to debut"],
#  ['AAPL',
#   'Jun-30-22',
#   '11:44AM',
#   'Why Amazon, Apple, and Nvidia Are Falling Today'],
#  ['AAPL',
#   'Jun-30-22',
#   '11:34AM',
#   'Tech stocks: Nasdaq having its worst year ever'],
#  ['AAPL', 'Jun-30-22', '11:09AM', '3 Reasons Why Apple Stock Is a Buy'],
#  ['AAPL',
#   'Jun-30-22',
#   '10:51AM',
#   'Companies are spending more money on private jets'],
#  ['AAPL',
#   'Jun-30-22',
#   '10:42AM',
#   'Top Millennial, Gen Z Stocks Shift To Energy Plays; Popular Pick Tesla Cuts Hundreds Of Autopilot Workers'],
#  ['AAPL',
#   'Jun-30-22',
#   '10:04AM',
#   'FCC Commissioner on TikTok: There are lots of reasons to be concerned'],
#  ['AAPL', 'Jun-30-22', '09:50AM', 'This FAANG Stock Is Too Cheap to Ignore'],
#  ['AAPL',
#   'Jun-30-22',
#   '09:47AM',
#   'All 30 Dow stocks are falling, with Goldman Sachs and Salesforce the biggest drags'],
#  ['AAPL',
#   'Jun-30-22',
#   '09:35AM',
#   '3 Stocks That Turned $1,000 Into Half a Million Dollars'],
#  ['AAPL',
#   'Jun-30-22',
#   '08:00AM',
#   'Why Not Every Break Of Support Is A Sell Signal'],
#  ['AAPL',
#   'Jun-30-22',
#   '08:00AM',
#   "Disney's Streaming Strategy Is a Home Run -- Here's Why"],
#  ['AAPL',
#   'Jun-30-22',
#   '07:20AM',
#   "These 3 Dow Stocks Are Set to Soar in 2022's Second Half and Beyond"],
#  ['AAPL',
#   'Jun-30-22',
#   '07:06AM',
#   'Apple eyes fuel purchases from dashboard as it revs up car software'],
#  ['AAPL',
#   'Jun-30-22',
#   '07:05AM',
#   'Down 20% in 6 Months, Is Now the Time to Buy Apple Stock?'],
#  ['AAPL',
#   'Jun-30-22',
#   '07:00AM',
#   'FOCUS-Apple eyes fuel purchases from dashboard as it revs up car software'],
#  ['AAPL',
#   'Jun-30-22',
#   '06:37AM',
#   'Crypto Winter Is Coming After SEC Rejects Key Bitcoin ETF'],
#  ['AAPL',
#   'Jun-30-22',
#   '06:30AM',
#   'Qualcomms Apple Slice Still Has an Expiration Date'],
#  ['AAPL',
#   'Jun-30-22',
#   '06:00AM',
#   'Influencers with Andy Serwer: Costis Maglaras'],
#  ['AAPL',
#   'Jun-30-22',
#   '03:27AM',
#   'FCCs Commissioner Carr Wants TikTok Yanked From Apple and Google App Stores'],
#  ['AAPL',
#   'Jun-30-22',
#   '01:16AM',
#   'Samsung Is First to Start Mass Production of 3-Nanometer Chips'],
#  ['AAPL',
#   'Jun-29-22',
#   '11:00PM',
#   'Inside Didis $60 Billion Crash That Changed China Tech Forever'],
#  ['AAPL',
#   'Jun-29-22',
#   '07:29PM',
#   'A U.S. FCC commissioner urges Apple, Google to boot TikTok from app stores'],
#  ['AAPL',
#   'Jun-29-22',
#   '05:48PM',
#   'TikTok Should Be Banned by Apple and Google App Stores, Trump-Appointed FCC Commissioner Opines'],
#  ['AAPL',
#   'Jun-29-22',
#   '05:07PM',
#   'Apple celebrates 15-year anniversary of the iPhone'],
#  ['AAPL',
#   'Jun-29-22',
#   '05:03PM',
#   "Roe v. Wade: Companies must create culture of 'psychological safety,' expert says"],
#  ['AAPL',
#   'Jun-29-22',
#   '04:12PM',
#   'FCC Member Calls On Apple, Google to Banish TikTok'],
#  ['AAPL',
#   'Jun-29-22',
#   '04:06PM',
#   'Stocks finish mixed as bitcoin fights to stay above $20,000'],
#  ['AAPL',
#   'Jun-29-22',
#   '03:48PM',
#   'FCC Official Wants App Stores to Cancel TikTok. Thats Unlikely'],
#  ['AAPL',
#   'Jun-29-22',
#   '02:59PM',
#   'Roe decision magnifies data privacy concerns'],
#  ['AAPL',
#   'Jun-29-22',
#   '01:50PM',
#   'Stranger Things and beyond: Heres whats worth streaming in July 2022'],
#  ['AAPL',
#   'Jun-29-22',
#   '01:25PM',
#   "'Getting an MBA continues to be an incredibly good investment': Columbia Business School Dean"],
#  ['AAPL',
#   'Jun-29-22',
#   '01:22PM',
#   "America's tech giants have a new responsibility in the post-Roe world"],
#  ['AAPL', 'Jun-29-22', '01:06PM', 'Why Apple Stock Climbed on Wednesday'],
#  ['AAPL',
#   'Jun-29-22',
#   '12:57PM',
#   'TikTok should be banned from Apple and Google app stores, demands FCC commissioner'],
#  ['AAPL',
#   'Jun-29-22',
#   '12:41PM',
#   'Apple Investors Have Something New to Focus On: the iPhone 14'],
#  ['AAPL',
#   'Jun-29-22',
#   '12:39PM',
#   'Fed rolls out new index to flag early warning signs of distress in corporate bonds'],
#  ['AAPL',
#   'Jun-29-22',
#   '11:50AM',
#   'Apple iPhone continues to dominate smartphone market'],
#  ['AAPL',
#   'Jun-29-22',
#   '10:29AM',
#   'McCormick cuts outlook, General Mills tops earnings estimates, Shopify stock split goes into effect'],
#  ['AAPL',
#   'Jun-29-22',
#   '10:10AM',
#   'FCC commissioner asks Apple and Google to remove TIkTok'],
#  ['AAPL',
#   'Jun-29-22',
#   '09:39AM',
#   'JPMorgan Piles On With Estimate Cuts Before Earnings: Tech Watch'],
#  ['AAPL',
#   'Jun-29-22',
#   '09:00AM',
#   'Here is What to Know Beyond Why Apple Inc. (AAPL) is a Trending Stock'],
#  ['AAPL',
#   'Jun-29-22',
#   '08:14AM',
#   "China's smartphone makers gain ground in Russian market, says M.Video"],
#  ['AAPL',
#   'Jun-29-22',
#   '08:06AM',
#   "China's smartphone makers gain ground in Russian market, says M.Video"],
#  ['TSLA',
#   'Jul-03-22',
#   '07:49PM',
#   "Dow Jones Futures Fall: Don't Feed The Bear; BYD Leaves Tesla In The Dust"],
#  ['TSLA',
#   'Jul-03-22',
#   '12:23PM',
#   'California Governor Newsom Runs Ads in Florida Attacking GOP'],
#  ['TSLA',
#   'Jul-03-22',
#   '11:40AM',
#   'Teslas second-quarter sales drop amid supply-chain and other pandemic-linked problems'],
#  ['TSLA',
#   'Jul-03-22',
#   '10:56AM',
#   'Tesla Q2 deliveries hit by China shutdowns; says June was best month ever'],
#  ['TSLA',
#   'Jul-03-22',
#   '09:58AM',
#   'Teslas Bumpy Quarter Might Be About More Than Lockdowns in China'],
#  ['TSLA',
#   'Jul-03-22',
#   '09:54AM',
#   'China Hamstrung Tesla in the First Half of the Year. The Spotlight Now Will Be on Cash Flow.'],
#  ['TSLA',
#   'Jul-03-22',
#   '08:34AM',
#   "Tesla loses $440m as Elon Musk's Bitcoin bet sours"],
#  ['TSLA',
#   'Jul-03-22',
#   '08:11AM',
#   'Tesla Stock Vs. BYD Stock: New EV King Crushes Tesla In Q2 Sales'],
#  ['TSLA',
#   'Jul-03-22',
#   '07:40AM',
#   'China EV Sales Boom: BYD Reports Surging Q2 Sales As Xpeng Outsells Nio And Li Auto'],
#  ['TSLA',
#   'Jul-03-22',
#   '05:36AM',
#   'German road traffic agency says 59,000 Tesla vehicles have software glitch'],
#  ['TSLA',
#   'Jul-03-22',
#   '05:34AM',
#   'German road traffic agency says 59,000 Tesla vehicles have software glitch'],
#  ['TSLA',
#   'Jul-02-22',
#   '09:21PM',
#   'Tesla Rivals Challenge Its Lead as Nio Sets Encouraging Record'],
#  ['TSLA',
#   'Jul-02-22',
#   '08:15PM',
#   'Special treatment for Tesla not in Indias interest, Ola says'],
#  ['TSLA',
#   'Jul-02-22',
#   '04:08PM',
#   'Tesla deliveries fall due to China Covid shutdowns and supply shortages'],
#  ['TSLA', 'Jul-02-22', '01:02PM', 'Elon Musk Reappears In An Unusual Place'],
#  ['TSLA',
#   'Jul-02-22',
#   '01:00PM',
#   "Let's Shine a Light on Lucid Motors as It Slides Downhill"],
#  ['TSLA',
#   'Jul-02-22',
#   '12:50PM',
#   'Tesla Vehicle Deliveries Tumble After China Factory Shutdown'],
#  ['TSLA',
#   'Jul-02-22',
#   '12:29PM',
#   'Tesla Stock: Q2 Deliveries Below Estimates After Shanghai Production Woes'],
#  ['TSLA',
#   'Jul-02-22',
#   '12:27PM',
#   "UPDATE 3-Tesla's deliveries fall, hurt by China's COVID-related shutdown"],
#  ['TSLA',
#   'Jul-02-22',
#   '12:11PM',
#   "Tesla's deliveries fall, hurt by China's COVID-related shutdown"],
#  ['TSLA',
#   'Jul-02-22',
#   '12:10PM',
#   'Tesla Q2 Deliveries Slump To 254,695 As Shanghai Shutdown, Supply Chain Snarls Take Toll'],
#  ['TSLA',
#   'Jul-02-22',
#   '12:02PM',
#   'Tesla Vehicle Production & Deliveries and Date for Financial Results & Webcast for Second Quarter 2022'],
#  ['TSLA', 'Jul-02-22', '09:46AM', 'Ford Makes a Major Change'],
#  ['TSLA',
#   'Jul-02-22',
#   '09:34AM',
#   "Ford Makes a Major Change Its Customers Won't like"],
#  ['TSLA',
#   'Jul-02-22',
#   '09:32AM',
#   "1 Semiconductor Growth Stock You'll Wish You'd Bought on the Dip"],
#  ['TSLA',
#   'Jul-02-22',
#   '08:10AM',
#   "12% of Cathie Wood's Portfolio Is Invested in These 2 Growth Stocks"],
#  ['TSLA',
#   'Jul-02-22',
#   '08:00AM',
#   'Recession is inevitable: Elon Musk now thinks theres a greater than 50-50 chance that the economy will decline. Here are 3 simple ways to protect your money'],
#  ['TSLA',
#   'Jul-02-22',
#   '07:32AM',
#   "The Disconnect Between Tesla's Business and Stock Price Continues to Grow Wider"],
#  ['TSLA',
#   'Jul-02-22',
#   '04:45AM',
#   'Elon Musk Returns to Twitter, Posting Photo With Pope'],
#  ['TSLA',
#   'Jul-02-22',
#   '01:00AM',
#   'Elon Musk risks losing his electric car crown as Tesla rivals accelerate'],
#  ['TSLA',
#   'Jul-01-22',
#   '06:20PM',
#   'Tesla was hit with yet more lawsuits alleging racism and sexual harassment at its Fremont factory'],
#  ['TSLA',
#   'Jul-01-22',
#   '05:35PM',
#   'Why Rivian, Tesla, and Lucid Stocks Crashed in June'],
#  ['TSLA',
#   'Jul-01-22',
#   '04:36PM',
#   'NIO, XPeng and Li Auto Deliveries Set a Record. That Can Help Tesla Stock, Too.'],
#  ['TSLA',
#   'Jul-01-22',
#   '03:54PM',
#   'EV market is on fire amid high gas prices: CoPilot CEO'],
#  ['TSLA',
#   'Jul-01-22',
#   '02:22PM',
#   "The 'most important thing about day trading for retail investors"],
#  ['TSLA',
#   'Jul-01-22',
#   '01:55PM',
#   'UPDATE 1-Tesla hit by new lawsuit alleging racial abuse against Black workers'],
#  ['TSLA',
#   'Jul-01-22',
#   '01:31PM',
#   'Toyota Runs Out of US Tax Credits for EVs, Joining Tesla and GM'],
#  ['TSLA', 'Jul-01-22', '12:47PM', 'Why Tesla Shares Moved Higher Friday'],
#  ['TSLA',
#   'Jul-01-22',
#   '11:40AM',
#   "Will the Twitter-Musk deal close? 'Yes,' says the social media giant's chairman"],
#  ['TSLA',
#   'Jul-01-22',
#   '11:11AM',
#   'Meta, Coinbase, Tesla: All of the tech companies hitting the brakes on hiring'],
#  ['TSLA',
#   'Jul-01-22',
#   '11:01AM',
#   'Amazon, Disney, AT&T donated to abortion opponents, Tesla faces racial discrimination lawsuit'],
#  ['TSLA',
#   'Jul-01-22',
#   '10:23AM',
#   'Bond markets move to the downside, mega cap tech stocks hold on to gains'],
#  ['TSLA',
#   'Jul-01-22',
#   '10:14AM',
#   'Twitter chairman says company is committed to closing the transaction with Elon Musk'],
#  ['TSLA',
#   'Jul-01-22',
#   '10:04AM',
#   'Elon Musk Hasnt Tweeted in Days. No One Knows Why.'],
#  ['TSLA',
#   'Jul-01-22',
#   '09:57AM',
#   'GM earnings: Its a boy that cried wolf, analyst says'],
#  ['TSLA',
#   'Jul-01-22',
#   '09:52AM',
#   'Chinese automakers Nio, Xpeng, and Li Auto record major year-over-year delivery surges'],
#  ['TSLA',
#   'Jul-01-22',
#   '09:48AM',
#   'Dow Jones Climbs After Worst First Half Since 1962; Chinese EV Makers Report Strong Sales'],
#  ['TSLA',
#   'Jul-01-22',
#   '09:00AM',
#   'Column: The GOP is now complaining about environmentally conscious investing'],
#  ['TSLA',
#   'Jul-01-22',
#   '08:33AM',
#   'Tesla hit by new lawsuit alleging blatant, open and unmitigated racism'],
#  ['TSLA',
#   'Jul-01-22',
#   '08:02AM',
#   'Dow Jones Futures Fall On Micron Warning; Tesla Rivals Li, Nio Sales Boom'],
#  ['TSLA',
#   'Jul-01-22',
#   '07:33AM',
#   "Tesla's stock bounces into positive territory after China-based rivals report upbeat June deliveries"],
#  ['TSLA',
#   'Jul-01-22',
#   '07:31AM',
#   'The Zacks Analyst Blog Highlights Ford Motor, Tesla'],
#  ['TSLA',
#   'Jul-01-22',
#   '07:10AM',
#   'Tesla Q2 Deliveries In Focus Following Record Quarterly Stock Slump, China Shutdowns'],
#  ['TSLA',
#   'Jul-01-22',
#   '06:28AM',
#   'Why Goldman is still very cautious on the stock market'],
#  ['TSLA',
#   'Jul-01-22',
#   '06:00AM',
#   "GM in driver's seat as Toyota stumbles on chip shortages"],
#  ['TSLA',
#   'Jun-30-22',
#   '10:39PM',
#   'Tesla hit by new lawsuit alleging racial abuse against Black workers'],
#  ['TSLA',
#   'Jun-30-22',
#   '07:22PM',
#   'Elon Musk Takes Unusually Long Twitter Break'],
#  ['TSLA', 'Jun-30-22', '06:07PM', 'Why Tesla Stock Stalled Today'],
#  ['TSLA',
#   'Jun-30-22',
#   '05:26PM',
#   'Unity Software Becomes Latest Tech Company to Announce Layoffs'],
#  ['TSLA',
#   'Jun-30-22',
#   '04:42PM',
#   'These 10 stocks in the S&P 500 lost $4.2 trillion of investors money during the first half of 2022'],
#  ['TSLA',
#   'Jun-30-22',
#   '04:16PM',
#   'Elon Musk takes notice as Kia, Hyundai climb EV sales chart'],
#  ['TSLA',
#   'Jun-30-22',
#   '04:12PM',
#   'Tesla begins tracking office worker attendance'],
#  ['TSLA',
#   'Jun-30-22',
#   '04:02PM',
#   'Elon Musks 9-day Twitter silence is unusually long for him'],
#  ['TSLA',
#   'Jun-30-22',
#   '03:37PM',
#   'General Motors Slowly Ramps Up Electric Hummer Production'],
#  ['TSLA',
#   'Jun-30-22',
#   '03:14PM',
#   'Want to Save Your Retirement Fund? Tune Out the Talking Heads'],
#  ['TSLA', 'Jun-30-22', '02:05PM', 'Why Ford Motor Stock Sank Today'],
#  ['TSLA',
#   'Jun-30-22',
#   '01:23PM',
#   "VinFast's success could jolt Triangle's economy into hyperspeed"],
#  ['TSLA', 'Jun-30-22', '12:50PM', 'Tesla: Wall Street wary of Q2 deliveries'],
#  ['TSLA',
#   'Jun-30-22',
#   '12:43PM',
#   'Hyundai Causes a Stir With a Car That Will Make People Talk'],
#  ['TSLA',
#   'Jun-30-22',
#   '12:30PM',
#   'We are in a recession: Long-time bull Cathie Wood warns investors about the big problem in the economy. Heres what she likes today'],
#  ['TSLA',
#   'Jun-30-22',
#   '12:30PM',
#   "Hyundai Pulls Out All The Stops To Get Closer To Tesla's Throne"],
#  ['TSLA',
#   'Jun-30-22',
#   '12:29PM',
#   'ESG Managers Say Wave of Probes, Scorn Heralds Better Days Ahead'],
#  ['TSLA',
#   'Jun-30-22',
#   '12:09PM',
#   "Tesla's run of record deliveries may be reaching the end of the road"],
#  ['TSLA',
#   'Jun-30-22',
#   '11:49AM',
#   'Blockstream CEO details partnership with Tesla for solar-powered bitcoin mining'],
#  ['TSLA',
#   'Jun-30-22',
#   '11:37AM',
#   'RIVN Stock: Rivian To Power Up Its First Fast-Charging Network; Is Rivian Stock A Buy?'],
#  ['TSLA',
#   'Jun-30-22',
#   '11:34AM',
#   'Tech stocks: Nasdaq having its worst year ever'],
#  ['TSLA',
#   'Jun-30-22',
#   '11:01AM',
#   'Google searches for electric vehicles and Tesla climb amid high gas prices'],
#  ['TSLA',
#   'Jun-30-22',
#   '10:48AM',
#   'Tesla analysts lower Q2 electric vehicle delivery estimates'],
#  ['TSLA',
#   'Jun-30-22',
#   '10:42AM',
#   'Top Millennial, Gen Z Stocks Shift To Energy Plays; Popular Pick Tesla Cuts Hundreds Of Autopilot Workers'],
#  ['TSLA',
#   'Jun-30-22',
#   '10:18AM',
#   'Market check: Stocks sell off, bitcoin dips below $19,000'],
#  ['TSLA',
#   'Jun-30-22',
#   '09:56AM',
#   'Dow Jones Dives After Key Inflation Report'],
#  ['TSLA',
#   'Jun-30-22',
#   '09:33AM',
#   'Teslas June China Sales Are Key for the Stock'],
#  ['TSLA',
#   'Jun-30-22',
#   '09:02AM',
#   'Cathie Woods Latest Thoughts on Inflation and Her 10 Worst-Performing Stock Picks'],
#  ['TSLA',
#   'Jun-30-22',
#   '08:25AM',
#   "Want A $7,500 EV Tax Credit? Don't Buy A Tesla"],
#  ['TSLA',
#   'Jun-30-22',
#   '07:38AM',
#   'Tesla Deliveries Are Coming. The Line in the Sand Is 250,000 Cars.'],
#  ['TSLA',
#   'Jun-30-22',
#   '07:09AM',
#   'Tesla Ignoring Environmental Reporting, Says Data Tracker.'],
#  ['TSLA', 'Jun-30-22', '07:00AM', 'Can Dogecoin Reach $1 by 2030?'],
#  ['TSLA',
#   'Jun-30-22',
#   '06:51AM',
#   "Elon Musk escalates Teslas war on working from home with 'please explain' emails"],
#  ['TSLA',
#   'Jun-30-22',
#   '06:00AM',
#   'Influencers with Andy Serwer: Costis Maglaras'],
#  ['TSLA',
#   'Jun-30-22',
#   '06:00AM',
#   "Global response to climate will 'change the world over the next 75 years': Costis Maglaras"],
#  ['TSLA',
#   'Jun-30-22',
#   '05:56AM',
#   "The Most Important Lesson Alphabet and Tesla Investors Can Learn From Amazon's Stock Split"],
#  ['TSLA',
#   'Jun-30-22',
#   '05:30AM',
#   'Do All These Stock Splits Mean a Market Correction Was Imminent?'],
#  ['TSLA',
#   'Jun-30-22',
#   '05:00AM',
#   "3 things that will 'consume us' over the next several decades: Columbia Business School Dean"],
#  ['TSLA',
#   'Jun-29-22',
#   '09:20PM',
#   'Tesla: Street Expectations for Q2 Deliveries Are Too High, Says Analyst'],
#  ['TSLA',
#   'Jun-29-22',
#   '05:45PM',
#   'Tesla (TSLA) Dips More Than Broader Markets: What You Should Know'],
#  ['TSLA',
#   'Jun-29-22',
#   '05:10PM',
#   "Elon Musk: 'A Recession Is Inevitable' - Here Are 3 Investments To Keep You Afloat If He's Right"],
#  ['TSLA',
#   'Jun-29-22',
#   '05:03PM',
#   "Roe v. Wade: Companies must create culture of 'psychological safety,' expert says"],
#  ['TSLA',
#   'Jun-29-22',
#   '04:54PM',
#   'Tesla to lay off nearly 200 Autopilot employees, Bentley exec talks EV push'],
#  ['TSLA',
#   'Jun-29-22',
#   '04:49PM',
#   'Chryslers Parent Says EVs Could Tank the Car Market. Why Thats Wrong.'],
#  ['TSLA',
#   'Jun-29-22',
#   '04:34PM',
#   'Dow Jones Up As Powell Issues This Inflation Warning; Tesla Stock Falls Amid This Move; Apple Pops'],
#  ['AMZN',
#   'Jul-03-22',
#   '07:29PM',
#   'Bezos Criticizes Bidens Call for Gas Stations to Cut Prices'],
#  ['AMZN',
#   'Jul-03-22',
#   '07:03PM',
#   'Oil Stabilizes as Traders Weigh Recession Concerns, Tight Supply'],
#  ['AMZN',
#   'Jul-03-22',
#   '07:01PM',
#   'WeShop launches as first community-owned shopping platform with IPO in sight'],
#  ['AMZN',
#   'Jul-03-22',
#   '07:00PM',
#   'Amazon to swap vans for walking and cargo bikes in Central London'],
#  ['AMZN',
#   'Jul-03-22',
#   '04:47PM',
#   'Jeff Bezos clashes with Biden administration again over inflation'],
#  ['AMZN', 'Jul-03-22', '07:52AM', '2 Top AI Stocks Ready for a Bull Run'],
#  ['AMZN',
#   'Jul-02-22',
#   '12:42PM',
#   'Amazon Gets A Stronger Hold Of Sports Streaming, Wins Bid For Champions League Football'],
#  ['AMZN',
#   'Jul-02-22',
#   '11:37AM',
#   '2 Bargain Stocks You Can Buy Today and Hold Forever'],
#  ['AMZN',
#   'Jul-02-22',
#   '10:35AM',
#   "You Won't Want to Miss This Dividend Stock's Bright Future"],
#  ['AMZN',
#   'Jul-02-22',
#   '08:00AM',
#   'Will This Spotify Acquisition Strengthen Ad Revenue?'],
#  ['AMZN',
#   'Jul-02-22',
#   '07:55AM',
#   'Facebook Slams the Brakes on Hiring: Should You Sell Meta Stock?'],
#  ['AMZN',
#   'Jul-02-22',
#   '07:05AM',
#   "Carvana's Stock Is Down 90%. Here's Why It's a Buy"],
#  ['AMZN', 'Jul-02-22', '07:01AM', 'Could Prologis Be in Trouble?'],
#  ['AMZN',
#   'Jul-02-22',
#   '06:53AM',
#   'Stock Market Plunge: 2 Buffett Stocks to Buy Now and Hold Forever'],
#  ['AMZN',
#   'Jul-01-22',
#   '06:55PM',
#   '5-Star Analyst Pounds the Table on Amazon Stock'],
#  ['AMZN',
#   'Jul-01-22',
#   '04:44PM',
#   'Fourth of July deals: Where to save on patio furniture, appliances, and mattresses'],
#  ['AMZN',
#   'Jul-01-22',
#   '04:25PM',
#   'Best-Selling Espresso Maker is Already 33% Off For Prime Day'],
#  ['AMZN',
#   'Jul-01-22',
#   '04:20PM',
#   'Stocks close higher, 10-year Treasury yield drops, crude oil rises'],
#  ['AMZN',
#   'Jul-01-22',
#   '01:28PM',
#   'Why Amazon, MercadoLibre, and Roku Stocks Moved Higher on Friday'],
#  ['AMZN',
#   'Jul-01-22',
#   '12:51PM',
#   "Meta wants to be more ruthless. It can't fall into its old habits."],
#  ['AMZN',
#   'Jul-01-22',
#   '11:11AM',
#   'Meta, Coinbase, Tesla: All of the tech companies hitting the brakes on hiring'],
#  ['AMZN',
#   'Jul-01-22',
#   '11:07AM',
#   '3 Reasons to Buy Amazon Stock (After the Stock Split)'],
#  ['AMZN',
#   'Jul-01-22',
#   '11:01AM',
#   'Amazon, Disney, AT&T donated to abortion opponents, Tesla faces racial discrimination lawsuit'],
#  ['AMZN',
#   'Jul-01-22',
#   '10:23AM',
#   'Bond markets move to the downside, mega cap tech stocks hold on to gains'],
#  ['AMZN',
#   'Jul-01-22',
#   '10:11AM',
#   "Amazon's (AMZN) New MoUs Boost Expansion Strategy in India"],
#  ['AMZN',
#   'Jul-01-22',
#   '09:57AM',
#   'GM earnings: Its a boy that cried wolf, analyst says'],
#  ['AMZN',
#   'Jul-01-22',
#   '09:54AM',
#   'Amazon vs. Microsoft Stock: Which is a Better Buy Right Now?'],
#  ['AMZN',
#   'Jul-01-22',
#   '09:35AM',
#   'Why Albertsons Was a Dog of a Stock This Week'],
#  ['AMZN',
#   'Jul-01-22',
#   '08:52AM',
#   'Michael Burrys Latest Warning on Bullwhip Effect and 10 Retail Stocks to Watch'],
#  ['AMZN',
#   'Jul-01-22',
#   '08:45AM',
#   '3 Reasons to Sell a Stock, and 1 Big Reason Not To'],
#  ['AMZN',
#   'Jul-01-22',
#   '08:30AM',
#   '3 Buffett Stocks That Are Screaming Buys Right Now'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:52AM',
#   'Beyond Stock Splits: 3 Top Growth Stocks to Buy Now'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:37AM',
#   'UPDATE 1-Amazon to allow Prime users to unsubscribe in two clicks after EU complaints'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:35AM',
#   'Stock Market Dip: 3 Companies to Buy and Hold for the Long Term'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:25AM',
#   'Why Is Everyone Talking About Bed Bath & Beyond Stock?'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:23AM',
#   'Amazon signs Champions League football streaming deal in UK'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:11AM',
#   'Amazon to allow Prime users to unsubscribe in two clicks after EU complaints'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:05AM',
#   'Amazon to allow Prime users to unsubscribe in two clicks after EU complaints'],
#  ['AMZN',
#   'Jul-01-22',
#   '07:01AM',
#   'Salesforce co-CEO Bret Taylor: Automation is crucial, even amid a slowing economy'],
#  ['AMZN', 'Jul-01-22', '07:01AM', '2 Reasons to Buy Amazon Stock Now'],
#  ['AMZN', 'Jul-01-22', '05:57AM', '5 Top Stocks for July'],
#  ['AMZN',
#   'Jul-01-22',
#   '05:21AM',
#   'Better Stock-Split Stock to Buy Right Now: Amazon or Alphabet?'],
#  ['AMZN',
#   'Jul-01-22',
#   '12:39AM',
#   "DSA says there's progress to report in effort to turn around downtown"],
#  ['AMZN',
#   'Jun-30-22',
#   '08:02PM',
#   '3 Remarkable Growth Stocks That Could Lead the Market Recovery in the Second Half of 2022'],
#  ['AMZN',
#   'Jun-30-22',
#   '07:41PM',
#   'Oracle Quietly Adds Abortion Travel Reimbursement Benefits'],
#  ['AMZN',
#   'Jun-30-22',
#   '06:27PM',
#   "Here's How to Get $60 in Free Money for Amazon Prime Day 2022"],
#  ['AMZN',
#   'Jun-30-22',
#   '05:20PM',
#   'Is Amazon Stock A Buy Or Sell As Business Performance Hit By Big Events'],
#  ['AMZN',
#   'Jun-30-22',
#   '05:06PM',
#   'Outgoing Amazon SVP tapped to lead Bay Area digital pharmacy startup'],
#  ['AMZN',
#   'Jun-30-22',
#   '04:42PM',
#   'These 10 stocks in the S&P 500 lost $4.2 trillion of investors money during the first half of 2022'],
#  ['AMZN',
#   'Jun-30-22',
#   '01:52PM',
#   'Worlds Biggest Ever Carbon Credits Issue Planned in Gabon'],
#  ['AMZN',
#   'Jun-30-22',
#   '01:43PM',
#   "Bed Bath & Beyond's liquidity 'circles the drain,' BofA warns"],
#  ['AMZN',
#   'Jun-30-22',
#   '01:01PM',
#   'Despite plenty of talk, many U.S. companies have still not fully exited Russia: Moral Rating Agency'],
#  ['AMZN',
#   'Jun-30-22',
#   '01:00PM',
#   'The Best Early Amazon Prime Day Deals of 2022: Save on Tech, Home, and Fashion'],
#  ['AMZN',
#   'Jun-30-22',
#   '12:44PM',
#   "Amazon's Latest Move Reflects Appetite For Expensive Sports Broadcast To Boost Prime Revenue"],
#  ['AMZN',
#   'Jun-30-22',
#   '12:26PM',
#   'Top Research Reports for Amazon, Accenture & Comcast'],
#  ['AMZN',
#   'Jun-30-22',
#   '12:07PM',
#   "Some streaming ads go to waste, new 'Stranger Things' set to debut"],
#  ['AMZN',
#   'Jun-30-22',
#   '12:00PM',
#   'Lam Research (LRCX) Proceeds Well Toward Zero-Carbon Goals'],
#  ['AMZN',
#   'Jun-30-22',
#   '11:44AM',
#   'Why Amazon, Apple, and Nvidia Are Falling Today'],
#  ['AMZN',
#   'Jun-30-22',
#   '11:34AM',
#   'Tech stocks: Nasdaq having its worst year ever'],
#  ['AMZN',
#   'Jun-30-22',
#   '11:20AM',
#   'Amazon Amps Up Its Prime Day And Plans Another During Fall'],
#  ['AMZN',
#   'Jun-30-22',
#   '10:50AM',
#   '10 Small-Cap Stocks to Buy According to Ken Fisher'],
#  ['AMZN',
#   'Jun-30-22',
#   '10:43AM',
#   'Amazon blocks LGBTQ searches in UAE after political pressure'],
#  ['AMZN',
#   'Jun-30-22',
#   '10:18AM',
#   'Market check: Stocks sell off, bitcoin dips below $19,000'],
#  ['AMZN',
#   'Jun-30-22',
#   '09:57AM',
#   '5 High-Conviction Stocks to Buy in This Market Correction'],
#  ['AMZN',
#   'Jun-30-22',
#   '09:41AM',
#   'Walgreens earnings top estimates, sales drop 4.2%'],
#  ['AMZN',
#   'Jun-30-22',
#   '09:35AM',
#   '3 Stocks That Turned $1,000 Into Half a Million Dollars'],
#  ['AMZN',
#   'Jun-30-22',
#   '09:02AM',
#   'Cathie Woods Latest Thoughts on Inflation and Her 10 Worst-Performing Stock Picks'],
#  ['AMZN',
#   'Jun-30-22',
#   '08:20AM',
#   '2 Reasons to Buy DigitalOcean Stock, and 1 Reason to Sell'],
#  ['AMZN',
#   'Jun-30-22',
#   '08:00AM',
#   '3 Recent Stock Splits That Are Begging to Be Bought'],
#  ['AMZN',
#   'Jun-30-22',
#   '08:00AM',
#   '1 Metric All Investors Should Consider Before Buying a New Stock'],
#  ['AMZN',
#   'Jun-30-22',
#   '07:30AM',
#   'Finance Chiefs Weigh Costs and Benefits of Stock Splits'],
#  ['AMZN',
#   'Jun-30-22',
#   '06:37AM',
#   'Amazon vs. the S&P 500: Which Is the Better First Investment?'],
#  ['AMZN',
#   'Jun-30-22',
#   '06:21AM',
#   '3 Unstoppable Investments Everyone Needs in Their Portfolios'],
#  ['AMZN',
#   'Jun-30-22',
#   '06:00AM',
#   'Influencers with Andy Serwer: Costis Maglaras'],
#  ['AMZN',
#   'Jun-30-22',
#   '06:00AM',
#   "Amazon's Stock Split Is Complete, but the Impact May Come Later"],
#  ['AMZN',
#   'Jun-30-22',
#   '05:56AM',
#   "The Most Important Lesson Alphabet and Tesla Investors Can Learn From Amazon's Stock Split"],
#  ['AMZN',
#   'Jun-30-22',
#   '05:30AM',
#   'Do All These Stock Splits Mean a Market Correction Was Imminent?'],
#  ['AMZN',
#   'Jun-30-22',
#   '01:27AM',
#   'Lenskart in $400 Million Deal to Create Asian Eyewear Giant'],
#  ['AMZN',
#   'Jun-29-22',
#   '06:38PM',
#   'Amazon, Rite Aid cap purchase of Plan B emergency contraceptives due to demand'],
#  ['AMZN',
#   'Jun-29-22',
#   '05:54PM',
#   'Why Amazon Stock Rose While the Market Slept Today'],
#  ['AMZN',
#   'Jun-29-22',
#   '05:52PM',
#   'Plan B is in such high demand after Roe v. Wade was overturned that Amazon has limited purchases'],
#  ['AMZN',
#   'Jun-29-22',
#   '05:45PM',
#   'Amazon (AMZN) Gains As Market Dips: What You Should Know'],
#  ['AMZN',
#   'Jun-29-22',
#   '05:36PM',
#   'Veev takes more than 500,000 square feet in sublease from Amazon'],
#  ['AMZN',
#   'Jun-29-22',
#   '05:03PM',
#   "Roe v. Wade: Companies must create culture of 'psychological safety,' expert says"],
#  ['AMZN',
#   'Jun-29-22',
#   '04:58PM',
#   'As Bed Bath and Pinterest Stocks Tumble, Their CEOs Are Collateral Damage'],
#  ['AMZN',
#   'Jun-29-22',
#   '04:49PM',
#   'What to Do With Office Space in This COVID World'],
#  ['AMZN',
#   'Jun-29-22',
#   '04:11PM',
#   'Amazon Shares Could Nearly Triple From Here, One Analyst Says'],
#  ['AMZN',
#   'Jun-29-22',
#   '04:05PM',
#   'Are Amazon Shares Worth a Look Post-Split?'],
#  ['AMZN',
#   'Jun-29-22',
#   '02:43PM',
#   'Financier Chanos Sees Golden Opportunity For Amazon, Microsoft, Google'],
#  ['AMZN',
#   'Jun-29-22',
#   '02:43PM',
#   'Challenges facing ousted Bed Bath & Beyond CEO became quickly insurmountable: retail expert'],
#  ['AMZN',
#   'Jun-29-22',
#   '02:15PM',
#   "Bed Bath & Beyond is 'in the end days' after 'dumpster fire' quarter, analyst says"],
#  ['AMZN',
#   'Jun-29-22',
#   '02:04PM',
#   'Companies covering abortion travel costs for employees now include Target, Yahoo and P&G'],
#  ['AMZN',
#   'Jun-29-22',
#   '01:50PM',
#   'Stranger Things and beyond: Heres whats worth streaming in July 2022'],
#  ['AMZN',
#   'Jun-29-22',
#   '01:25PM',
#   "'Getting an MBA continues to be an incredibly good investment': Columbia Business School Dean"],
#  ['AMZN',
#   'Jun-29-22',
#   '12:47PM',
#   'Amazon Plans to Share Cashierless Store Data With Brands and Advertisers'],
#  ['AMZN',
#   'Jun-29-22',
#   '11:26AM',
#   'CEO resignations: 668 executives have left their posts since January'],
#  ['AMZN',
#   'Jun-29-22',
#   '10:53AM',
#   '2 Reasons MercadoLibre Can Bounce Back Big Time'],
#  ['AMZN',
#   'Jun-29-22',
#   '10:29AM',
#   'McCormick cuts outlook, General Mills tops earnings estimates, Shopify stock split goes into effect'],
#  ['AMZN',
#   'Jun-29-22',
#   '09:54AM',
#   'Ecuador President Survives Impeachment Attempt Amid Unrest'],
#  ['AMZN',
#   'Jun-29-22',
#   '09:39AM',
#   'JPMorgan Piles On With Estimate Cuts Before Earnings: Tech Watch']]

# %%
# 使用nltk，分析每個標題的極性分數，
# 範圍為 -1 到 1，-1 表示高度負面，高度 1 表示正面。
analyzer = SentimentIntensityAnalyzer()

columns = ['Ticker', 'Date', 'Time', 'Headline']
news = pd.DataFrame(parsed_news, columns=columns)
scores = news['Headline'].apply(analyzer.polarity_scores).tolist()

df_scores = pd.DataFrame(scores)
news = news.join(df_scores, rsuffix='_right')

df_scores
# Out:
#        neg    neu    pos  compound
# 0    0.152  0.635  0.213    0.2960
# 1    0.167  0.833  0.000   -0.2960
# 2    0.000  0.730  0.270    0.5719
# 3    0.241  0.535  0.225    0.1779
# 4    0.000  0.762  0.238    0.3612
# ..     ...    ...    ...       ...
# 295  0.196  0.804  0.000   -0.2960
# 296  0.000  1.000  0.000    0.0000
# 297  0.126  0.686  0.189    0.2732
# 298  0.000  1.000  0.000    0.0000
# 299  0.196  0.804  0.000   -0.2960
#
# [300 rows x 4 columns]

# %%
news
# Out:
#     Ticker       Date     Time  \
# 0     AAPL  Jul-03-22  04:35PM
# 1     AAPL  Jul-03-22  10:00AM
# 2     AAPL  Jul-03-22  05:45AM
# 3     AAPL  Jul-02-22  02:00PM
# 4     AAPL  Jul-02-22  09:00AM
# ..     ...        ...      ...
# 295   AMZN  Jun-29-22  11:26AM
# 296   AMZN  Jun-29-22  10:53AM
# 297   AMZN  Jun-29-22  10:29AM
# 298   AMZN  Jun-29-22  09:54AM
# 299   AMZN  Jun-29-22  09:39AM
#
#                                               Headline    neg    neu    pos  \
# 0    Theyll chicken out: Fund legend Rick Rule says...  0.152  0.635  0.213
# 1    Worried About Personal Data Leaks? Heres How t...  0.167  0.833  0.000
# 2    Learn This Investing Lesson, And You'll Have t...  0.000  0.730  0.270
# 3    Here Are 2 of the Best Stocks to Buy if the U....  0.241  0.535  0.225
# 4    Will the Apple and MLS Deal Attract a New Gene...  0.000  0.762  0.238
# ..                                                 ...    ...    ...    ...
# 295  CEO resignations: 668 executives have left the...  0.196  0.804  0.000
# 296    2 Reasons MercadoLibre Can Bounce Back Big Time  0.000  1.000  0.000
# 297  McCormick cuts outlook, General Mills tops ear...  0.126  0.686  0.189
# 298  Ecuador President Survives Impeachment Attempt...  0.000  1.000  0.000
# 299  JPMorgan Piles On With Estimate Cuts Before Ea...  0.196  0.804  0.000
#
#      compound
# 0      0.2960
# 1     -0.2960
# 2      0.5719
# 3      0.1779
# 4      0.3612
# ..        ...
# 295   -0.2960
# 296    0.0000
# 297    0.2732
# 298    0.0000
# 299   -0.2960
#
# [300 rows x 8 columns]

# %%
# 數據已準備好以吸引人的方式進行操作和查看。
# 對於輸入列表中的每個代碼，將創建一個新的 DataFrame，其中包括其標題及其各自的分數。
# 創建一個最終的 DataFrame，其中包括每個股票代碼在所有最近解析的新聞中的平均情緒值。
news['Date'] = pd.to_datetime(news.Date).dt.date

unique_ticker = news['Ticker'].unique().tolist()
news_dict = {name: news.loc[news['Ticker'] == name] for name in unique_ticker}

news
# Out:
#     Ticker        Date     Time  \
# 0     AAPL  2022-07-03  04:35PM
# 1     AAPL  2022-07-03  10:00AM
# 2     AAPL  2022-07-03  05:45AM
# 3     AAPL  2022-07-02  02:00PM
# 4     AAPL  2022-07-02  09:00AM
# ..     ...         ...      ...
# 295   AMZN  2022-06-29  11:26AM
# 296   AMZN  2022-06-29  10:53AM
# 297   AMZN  2022-06-29  10:29AM
# 298   AMZN  2022-06-29  09:54AM
# 299   AMZN  2022-06-29  09:39AM
#
#                                               Headline    neg    neu    pos  \
# 0    Theyll chicken out: Fund legend Rick Rule says...  0.152  0.635  0.213
# 1    Worried About Personal Data Leaks? Heres How t...  0.167  0.833  0.000
# 2    Learn This Investing Lesson, And You'll Have t...  0.000  0.730  0.270
# 3    Here Are 2 of the Best Stocks to Buy if the U....  0.241  0.535  0.225
# 4    Will the Apple and MLS Deal Attract a New Gene...  0.000  0.762  0.238
# ..                                                 ...    ...    ...    ...
# 295  CEO resignations: 668 executives have left the...  0.196  0.804  0.000
# 296    2 Reasons MercadoLibre Can Bounce Back Big Time  0.000  1.000  0.000
# 297  McCormick cuts outlook, General Mills tops ear...  0.126  0.686  0.189
# 298  Ecuador President Survives Impeachment Attempt...  0.000  1.000  0.000
# 299  JPMorgan Piles On With Estimate Cuts Before Ea...  0.196  0.804  0.000
#
#      compound
# 0      0.2960
# 1     -0.2960
# 2      0.5719
# 3      0.1779
# 4      0.3612
# ..        ...
# 295   -0.2960
# 296    0.0000
# 297    0.2732
# 298    0.0000
# 299   -0.2960
#
# [300 rows x 8 columns]

# %%
unique_ticker
# Out:
# ['AAPL', 'TSLA', 'AMZN']

# %%
news_dict
# Out:
# {'AAPL':    Ticker        Date     Time  \
#  0    AAPL  2022-07-03  04:35PM
#  1    AAPL  2022-07-03  10:00AM
#  2    AAPL  2022-07-03  05:45AM
#  3    AAPL  2022-07-02  02:00PM
#  4    AAPL  2022-07-02  09:00AM
#  ..    ...         ...      ...
#  95   AAPL  2022-06-29  10:10AM
#  96   AAPL  2022-06-29  09:39AM
#  97   AAPL  2022-06-29  09:00AM
#  98   AAPL  2022-06-29  08:14AM
#  99   AAPL  2022-06-29  08:06AM
#
#                                               Headline    neg    neu    pos  \
#  0   Theyll chicken out: Fund legend Rick Rule says...  0.152  0.635  0.213
#  1   Worried About Personal Data Leaks? Heres How t...  0.167  0.833  0.000
#  2   Learn This Investing Lesson, And You'll Have t...  0.000  0.730  0.270
#  3   Here Are 2 of the Best Stocks to Buy if the U....  0.241  0.535  0.225
#  4   Will the Apple and MLS Deal Attract a New Gene...  0.000  0.762  0.238
#  ..                                                ...    ...    ...    ...
#  95  FCC commissioner asks Apple and Google to remo...  0.000  1.000  0.000
#  96  JPMorgan Piles On With Estimate Cuts Before Ea...  0.196  0.804  0.000
#  97  Here is What to Know Beyond Why Apple Inc. (AA...  0.000  1.000  0.000
#  98  China's smartphone makers gain ground in Russi...  0.000  0.726  0.274
#  99  China's smartphone makers gain ground in Russi...  0.000  0.726  0.274
#
#      compound
#  0     0.2960
#  1    -0.2960
#  2     0.5719
#  3     0.1779
#  4     0.3612
#  ..       ...
#  95    0.0000
#  96   -0.2960
#  97    0.0000
#  98    0.5267
#  99    0.5267
#
#  [100 rows x 8 columns],
#  'TSLA':     Ticker        Date     Time  \
#  100   TSLA  2022-07-03  07:49PM
#  101   TSLA  2022-07-03  12:23PM
#  102   TSLA  2022-07-03  11:40AM
#  103   TSLA  2022-07-03  10:56AM
#  104   TSLA  2022-07-03  09:58AM
#  ..     ...         ...      ...
#  195   TSLA  2022-06-29  05:10PM
#  196   TSLA  2022-06-29  05:03PM
#  197   TSLA  2022-06-29  04:54PM
#  198   TSLA  2022-06-29  04:49PM
#  199   TSLA  2022-06-29  04:34PM
#
#                                                Headline    neg    neu    pos  \
#  100  Dow Jones Futures Fall: Don't Feed The Bear; B...  0.000  1.000  0.000
#  101  California Governor Newsom Runs Ads in Florida...  0.273  0.727  0.000
#  102  Teslas second-quarter sales drop amid supply-c...  0.375  0.625  0.000
#  103  Tesla Q2 deliveries hit by China shutdowns; sa...  0.000  0.741  0.259
#  104  Teslas Bumpy Quarter Might Be About More Than ...  0.000  1.000  0.000
#  ..                                                 ...    ...    ...    ...
#  195  Elon Musk: 'A Recession Is Inevitable' - Here ...  0.157  0.843  0.000
#  196  Roe v. Wade: Companies must create culture of ...  0.000  0.840  0.160
#  197  Tesla to lay off nearly 200 Autopilot employee...  0.000  1.000  0.000
#  198  Chryslers Parent Says EVs Could Tank the Car M...  0.220  0.780  0.000
#  199  Dow Jones Up As Powell Issues This Inflation W...  0.130  0.870  0.000
#
#       compound
#  100    0.0000
#  101   -0.4588
#  102   -0.5859
#  103    0.6369
#  104    0.0000
#  ..        ...
#  195   -0.4215
#  196    0.2732
#  197    0.0000
#  198   -0.4767
#  199   -0.3400
#
#  [100 rows x 8 columns],
#  'AMZN':     Ticker        Date     Time  \
#  200   AMZN  2022-07-03  07:29PM
#  201   AMZN  2022-07-03  07:03PM
#  202   AMZN  2022-07-03  07:01PM
#  203   AMZN  2022-07-03  07:00PM
#  204   AMZN  2022-07-03  04:47PM
#  ..     ...         ...      ...
#  295   AMZN  2022-06-29  11:26AM
#  296   AMZN  2022-06-29  10:53AM
#  297   AMZN  2022-06-29  10:29AM
#  298   AMZN  2022-06-29  09:54AM
#  299   AMZN  2022-06-29  09:39AM
#
#                                                Headline    neg    neu    pos  \
#  200  Bezos Criticizes Bidens Call for Gas Stations ...  0.360  0.640  0.000
#  201  Oil Stabilizes as Traders Weigh Recession Conc...  0.259  0.741  0.000
#  202  WeShop launches as first community-owned shopp...  0.000  1.000  0.000
#  203  Amazon to swap vans for walking and cargo bike...  0.000  0.866  0.134
#  204  Jeff Bezos clashes with Biden administration a...  0.000  1.000  0.000
#  ..                                                 ...    ...    ...    ...
#  295  CEO resignations: 668 executives have left the...  0.196  0.804  0.000
#  296    2 Reasons MercadoLibre Can Bounce Back Big Time  0.000  1.000  0.000
#  297  McCormick cuts outlook, General Mills tops ear...  0.126  0.686  0.189
#  298  Ecuador President Survives Impeachment Attempt...  0.000  1.000  0.000
#  299  JPMorgan Piles On With Estimate Cuts Before Ea...  0.196  0.804  0.000
#
#       compound
#  200   -0.5423
#  201   -0.4215
#  202    0.0000
#  203    0.1779
#  204    0.0000
#  ..        ...
#  295   -0.2960
#  296    0.0000
#  297    0.2732
#  298    0.0000
#  299   -0.2960
#
#  [100 rows x 8 columns]}

# %%
values = []
for ticker in tickers: 
    dataframe = news_dict[ticker]
    dataframe = dataframe.set_index('Ticker')
    dataframe = dataframe.drop(columns = ['Headline'])
    print ('\n')
    print (dataframe.head())
    
    mean = round(dataframe['compound'].mean(), 2)
    values.append(mean)
#dataframe
# Out:
#               Date     Time    neg    neu    pos  compound
# Ticker
# AAPL    2022-07-03  04:35PM  0.152  0.635  0.213    0.2960
# AAPL    2022-07-03  10:00AM  0.167  0.833  0.000   -0.2960
# AAPL    2022-07-03  05:45AM  0.000  0.730  0.270    0.5719
# AAPL    2022-07-02  02:00PM  0.241  0.535  0.225    0.1779
# AAPL    2022-07-02  09:00AM  0.000  0.762  0.238    0.3612
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# TSLA    2022-07-03  07:49PM  0.000  1.000  0.000    0.0000
# TSLA    2022-07-03  12:23PM  0.273  0.727  0.000   -0.4588
# TSLA    2022-07-03  11:40AM  0.375  0.625  0.000   -0.5859
# TSLA    2022-07-03  10:56AM  0.000  0.741  0.259    0.6369
# TSLA    2022-07-03  09:58AM  0.000  1.000  0.000    0.0000
#
#
#               Date     Time    neg    neu    pos  compound
# Ticker
# AMZN    2022-07-03  07:29PM  0.360  0.640  0.000   -0.5423
# AMZN    2022-07-03  07:03PM  0.259  0.741  0.000   -0.4215
# AMZN    2022-07-03  07:01PM  0.000  1.000  0.000    0.0000
# AMZN    2022-07-03  07:00PM  0.000  0.866  0.134    0.1779
# AMZN    2022-07-03  04:47PM  0.000  1.000  0.000    0.0000

# %%
df = pd.DataFrame(list(zip(tickers, values)), columns =['Ticker', 'Mean Sentiment']) 
df = df.set_index('Ticker')
df = df.sort_values('Mean Sentiment', ascending=False)
print ('\n')
print (df)
# Out:
#         Mean Sentiment
# Ticker
# AMZN              0.10
# AAPL             -0.03
# TSLA             -0.06
